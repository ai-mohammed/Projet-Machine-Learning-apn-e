# %%
# Librairies classiques
import pandas as pd
import numpy as np

# Visualisation de données
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import seaborn as sns
from plotly.subplots import make_subplots

# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
df = pd.read_csv("Data\AIDA_Results_IA_Institut.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26841 entries, 0 to 26840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Start           26841 non-null  int64
#  1   Diver           26841 non-null  object
#  2   Gender          26841 non-null  object
#  3   Discipline      26841 non-null  object
#  4   Line            4694 non-null   float64
#  5   Official Top    26841 non-null  object
#  6   AP              26841 non-null  int64
#  7   RP              26841 non-null  object
#  8   Card            26841 non-null  object
#  9   Points          26841 non-null  object
#  10  Remarks         26836 non-null  object
#  11  Title Event     26841 non-null  object
#  12  Event Type      26841 non-null  object
#  13  Day             26841 non-null  object
#  14  Category Event  26841 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 3.1+ MB

# %%
df
# Out:
#        Start                         Diver Gender Discipline Official Top  AP  \
# 0          1         Tasos Grillakis (GRC)      M        FIM        00:00  33
# 1          2    Antonis Papantonatos (GRC)      M        FIM        00:00  55
# 2          3      Dimitris Koumoulos (GRC)      M        CNF        00:00  55
# 3          4   Christos Papadopoulos (GRC)      M        CWT        00:00  55
# 4          5            Anna Chalari (GRC)      F        CWT        00:00  15
# ...      ...                           ...    ...        ...          ...  ..
# 26836      7      Karine Le Flanchec (FRA)      F       CWTB        09:40  57
# 26837      8  Anne-Sophie Passalboni (FRA)      F        CWT        09:50  52
# 26838      9        Clementine Marie (FRA)      F        CNF        10:00  40
# 26839     10   Eisve Treciakauskaite (LTU)      F        CWT        10:10  33
# 26840     11   Mohammed Adem Alouach (DZA)      M        FIM        10:20  30
#
#          RP    Card Points          Remarks  \
# 0      23 m  YELLOW   12.0                -
# 1      47 m  YELLOW   38.0                -
# 2      55 m   WHITE   55.0                -
# 3      55 m   WHITE   55.0               OK
# 4      15 m   WHITE   15.0               OK
# ...     ...     ...    ...              ...
# 26836  57 m   WHITE     57               Ok
# 26837  52 m   WHITE     52               Ok
# 26838  40 m   WHITE     40               Ok
# 26839  28 m  YELLOW     22  No tag,under ap
# 26840  30 m   WHITE     30               Ok
#
#                               Title Event         Event Type         Day  \
# 0                        Depth Event 2016  Depth Competition  2016-07-17
# 1                        Depth Event 2016  Depth Competition  2016-07-17
# 2                        Depth Event 2016  Depth Competition  2016-07-17
# 3                        Depth Event 2016  Depth Competition  2016-07-17
# 4                        Depth Event 2016  Depth Competition  2016-07-17
# ...                                   ...                ...         ...
# 26836  The AIDA Cormorant Depth Challenge  Depth Competition  2023-07-23
# 26837  The AIDA Cormorant Depth Challenge  Depth Competition  2023-07-23
# 26838  The AIDA Cormorant Depth Challenge  Depth Competition  2023-07-23
# 26839  The AIDA Cormorant Depth Challenge  Depth Competition  2023-07-23
# 26840  The AIDA Cormorant Depth Challenge  Depth Competition  2023-07-23
#
#       Category Event
# 0              other
# 1              other
# 2              other
# 3              other
# 4              other
# ...              ...
# 26836          other
# 26837          other
# 26838          other
# 26839          other
# 26840          other
#
# [26841 rows x 14 columns]

# %% [markdown]
# ## Modifications des données

# %% [markdown]
# ### Drop de colonnes

# %%
df = df.drop(["Line"], axis=1)

# %% [markdown]
# ### Autres

# %% [markdown]
# ## ...

# %% [markdown]
# ## One hot encoder

# %%
# On sélectionne que les colonnes du dataset qui nous intéressent, et on les copies dans un nouveau DataFrame pour éviter les effets de bord.
df_mod = df[[]].copy()
df_mod
# Out:
#         carat_weight  depth_percent  table_percent  meas_length  meas_width  \
# 0               0.09           62.7           59.0         2.85        2.87
# 1               0.09           61.9           59.0         2.84        2.89
# 2               0.09           61.1           59.0         2.88        2.90
# 3               0.09           62.0           59.0         2.86        2.88
# 4               0.09           64.9           58.5         2.79        2.83
# ...              ...            ...            ...          ...         ...
# 219698         10.65           61.3           58.0        14.06       14.18
# 219699          5.17           64.8           65.0        11.55        8.81
# 219700         18.07           60.2           59.0        17.06       17.10
# 219701          0.90           70.8           72.0         5.22        4.90
# 219702         10.03           66.7           65.0        15.61       11.09
#
#         meas_depth culet_size fluor_color eye_clean  total_sales_price
# 0             1.79          N     unknown   unknown                200
# 1             1.78          N     unknown   unknown                200
# 2             1.77    unknown     unknown   unknown                200
# 3             1.78    unknown     unknown   unknown                200
# 4             1.82          N     unknown   unknown                200
# ...            ...        ...         ...       ...                ...
# 219698        8.66          N     unknown   unknown            1210692
# 219699        5.71    unknown     unknown   unknown            1292500
# 219700       10.20          N     unknown   unknown            1315496
# 219701        3.47          N     unknown   unknown            1350000
# 219702        7.39    unknown     unknown   unknown            1449881
#
# [219703 rows x 10 columns]

# %%
# On utilise one_hot_encoder pour transformer les colonnes de données catégoriques en plusieurs colonnes à valeur numériques
one_hot_encoder = OneHotEncoder()

# %%
# On intialise le transformer qui effectura les modifications que l'on souhaite
transformer = make_column_transformer(
    (OneHotEncoder(), []),
    remainder='passthrough')

# %%
# On transforme les données du DataFrame
transformed = transformer.fit_transform(df_mod)
transformed
# Out:
# array([[0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 2.870000e+00,
#         1.790000e+00, 2.000000e+02],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 2.890000e+00,
#         1.780000e+00, 2.000000e+02],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 2.900000e+00,
#         1.770000e+00, 2.000000e+02],
#        ...,
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 1.710000e+01,
#         1.020000e+01, 1.315496e+06],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 4.900000e+00,
#         3.470000e+00, 1.350000e+06],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 1.109000e+01,
#         7.390000e+00, 1.449881e+06]])

# %%
# On convertie ces données en DataFrame
transformed_df = pd.DataFrame(
    transformed, 
    columns=transformer.get_feature_names_out()
)

# %%
# Affiche le nom de toutes les colonnes du DataFrame transformé
transformer.get_feature_names_out()
# Out:
# array(['onehotencoder__culet_size_EL', 'onehotencoder__culet_size_L',
#        'onehotencoder__culet_size_M', 'onehotencoder__culet_size_N',
#        'onehotencoder__culet_size_S', 'onehotencoder__culet_size_SL',
#        'onehotencoder__culet_size_VL', 'onehotencoder__culet_size_VS',
#        'onehotencoder__culet_size_unknown',
#        'onehotencoder__fluor_color_Blue',
#        'onehotencoder__fluor_color_Green',
#        'onehotencoder__fluor_color_Orange',
#        'onehotencoder__fluor_color_White',
#        'onehotencoder__fluor_color_Yellow',
#        'onehotencoder__fluor_color_unknown',
#        'onehotencoder__eye_clean_Borderline',
#        'onehotencoder__eye_clean_E1', 'onehotencoder__eye_clean_No',
#        'onehotencoder__eye_clean_Yes', 'onehotencoder__eye_clean_unknown',
#        'remainder__carat_weight', 'remainder__depth_percent',
#        'remainder__table_percent', 'remainder__meas_length',
#        'remainder__meas_width', 'remainder__meas_depth',
#        'remainder__total_sales_price'], dtype=object)

# %%
# On vérifie que nos données sont complètes
transformed_df.isna().sum()
# Out:
# onehotencoder__culet_size_EL           0
# onehotencoder__culet_size_L            0
# onehotencoder__culet_size_M            0
# onehotencoder__culet_size_N            0
# onehotencoder__culet_size_S            0
# onehotencoder__culet_size_SL           0
# onehotencoder__culet_size_VL           0
# onehotencoder__culet_size_VS           0
# onehotencoder__culet_size_unknown      0
# onehotencoder__fluor_color_Blue        0
# onehotencoder__fluor_color_Green       0
# onehotencoder__fluor_color_Orange      0
# onehotencoder__fluor_color_White       0
# onehotencoder__fluor_color_Yellow      0
# onehotencoder__fluor_color_unknown     0
# onehotencoder__eye_clean_Borderline    0
# onehotencoder__eye_clean_E1            0
# onehotencoder__eye_clean_No            0
# onehotencoder__eye_clean_Yes           0
# onehotencoder__eye_clean_unknown       0
# remainder__carat_weight                0
# remainder__depth_percent               0
# remainder__table_percent               0
# remainder__meas_length                 0
# remainder__meas_width                  0
# remainder__meas_depth                  0
# remainder__total_sales_price           0
# dtype: int64

# %%
# Pour avoir un aperçu synthétique des donneés
transformed_df.describe()
# Out:
#        onehotencoder__culet_size_EL  onehotencoder__culet_size_L  \
# count                 219703.000000                219703.000000
# mean                       0.000018                     0.000264
# std                        0.004267                     0.016246
# min                        0.000000                     0.000000
# 25%                        0.000000                     0.000000
# 50%                        0.000000                     0.000000
# 75%                        0.000000                     0.000000
# max                        1.000000                     1.000000
#
#        onehotencoder__culet_size_M  onehotencoder__culet_size_N  \
# count                219703.000000                219703.000000
# mean                      0.000742                     0.600351
# std                       0.027228                     0.489827
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     1.000000
# 75%                       0.000000                     1.000000
# max                       1.000000                     1.000000
#
#        onehotencoder__culet_size_S  onehotencoder__culet_size_SL  \
# count                219703.000000                 219703.000000
# mean                      0.002167                      0.000064
# std                       0.046496                      0.007982
# min                       0.000000                      0.000000
# 25%                       0.000000                      0.000000
# 50%                       0.000000                      0.000000
# 75%                       0.000000                      0.000000
# max                       1.000000                      1.000000
#
#        onehotencoder__culet_size_VL  onehotencoder__culet_size_VS  \
# count                 219703.000000                 219703.000000
# mean                       0.000018                      0.006122
# std                        0.004267                      0.078003
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000
#
#        onehotencoder__culet_size_unknown  onehotencoder__fluor_color_Blue  \
# count                      219703.000000                    219703.000000
# mean                            0.390254                         0.069271
# std                             0.487808                         0.253915
# min                             0.000000                         0.000000
# 25%                             0.000000                         0.000000
# 50%                             0.000000                         0.000000
# 75%                             1.000000                         0.000000
# max                             1.000000                         1.000000
#
#        onehotencoder__fluor_color_Green  onehotencoder__fluor_color_Orange  \
# count                      219703.00000                      219703.000000
# mean                            0.00025                           0.000046
# std                             0.01582                           0.006746
# min                             0.00000                           0.000000
# 25%                             0.00000                           0.000000
# 50%                             0.00000                           0.000000
# 75%                             0.00000                           0.000000
# max                             1.00000                           1.000000
#
#        onehotencoder__fluor_color_White  onehotencoder__fluor_color_Yellow  \
# count                     219703.000000                      219703.000000
# mean                           0.000191                           0.001821
# std                            0.013825                           0.042630
# min                            0.000000                           0.000000
# 25%                            0.000000                           0.000000
# 50%                            0.000000                           0.000000
# 75%                            0.000000                           0.000000
# max                            1.000000                           1.000000
#
#        onehotencoder__fluor_color_unknown  \
# count                       219703.000000
# mean                             0.928422
# std                              0.257789
# min                              0.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              1.000000
#
#        onehotencoder__eye_clean_Borderline  onehotencoder__eye_clean_E1  \
# count                        219703.000000                219703.000000
# mean                              0.002344                     0.001365
# std                               0.048359                     0.036927
# min                               0.000000                     0.000000
# 25%                               0.000000                     0.000000
# 50%                               0.000000                     0.000000
# 75%                               0.000000                     0.000000
# max                               1.000000                     1.000000
#
#        onehotencoder__eye_clean_No  onehotencoder__eye_clean_Yes  \
# count                219703.000000                 219703.000000
# mean                      0.000187                      0.281885
# std                       0.013659                      0.449919
# min                       0.000000                      0.000000
# 25%                       0.000000                      0.000000
# 50%                       0.000000                      0.000000
# 75%                       0.000000                      1.000000
# max                       1.000000                      1.000000
#
#        onehotencoder__eye_clean_unknown  remainder__carat_weight  \
# count                     219703.000000            219703.000000
# mean                           0.714219                 0.755176
# std                            0.451787                 0.845894
# min                            0.000000                 0.080000
# 25%                            0.000000                 0.310000
# 50%                            1.000000                 0.500000
# 75%                            1.000000                 1.000000
# max                            1.000000                19.350000
#
#        remainder__depth_percent  remainder__table_percent  \
# count             219703.000000             219703.000000
# mean                  61.683768                 57.747585
# std                    9.915266                  9.959928
# min                    0.000000                  0.000000
# 25%                   61.200000                 57.000000
# 50%                   62.400000                 58.000000
# 75%                   63.500000                 60.000000
# max                   98.700000                 94.000000
#
#        remainder__meas_length  remainder__meas_width  remainder__meas_depth  \
# count           219703.000000          219703.000000          219703.000000
# mean                 5.548853               5.135626               3.285699
# std                  1.763924               1.374529               2.054822
# min                  0.000000               0.000000               0.000000
# 25%                  4.350000               4.310000               2.680000
# 50%                  5.060000               4.800000               3.030000
# 75%                  6.350000               5.700000               3.630000
# max                 93.660000              62.300000              76.300000
#
#        remainder__total_sales_price
# count                  2.197030e+05
# mean                   6.908062e+03
# std                    2.595949e+04
# min                    2.000000e+02
# 25%                    9.580000e+02
# 50%                    1.970000e+03
# 75%                    5.207000e+03
# max                    1.449881e+06
