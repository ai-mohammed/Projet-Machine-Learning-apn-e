# %%
import pandas as pd

# %%
df = pd.read_csv('Data/AIDA_Results_IA_Institut.csv')

# %%
# Mapping for gender and discipline
gender_map = {'M': 0, 'F': 1}
discipline_map = {'CNF': 0, 'FIM': 1, 'CWT': 2, 'CWT-B': 3}

# Transforming the 'Gender' column
df['Gender'] = df['Gender'].map(gender_map)

# Transforming the 'Discipline' column
df['Discipline'] = df['Discipline'].map(discipline_map)

# Removing rows where either 'Gender' or 'Discipline' is NaN (i.e., was other than specified categories)
df.dropna(subset=['Gender', 'Discipline'], inplace=True)

# %%
# 1. Extracting the month from the 'Day' column
df['Month'] = pd.to_datetime(df['Day']).dt.month

# 2. Calculating total dive experience
# Sorting data by 'Diver' and 'Day'
df.sort_values(by=['Diver', 'Day'], inplace=True)

# Cumulative count of dives per diver
df['Experience Dive'] = df.groupby('Diver').cumcount()

# 3. Calculating experience per discipline
# Cumulative count of dives per diver per discipline
df['Experience Discipline'] = df.groupby(['Diver', 'Discipline']).cumcount()

# Displaying the modified dataframe
df[['Diver', 'Day', 'Month', 'Discipline', 'Experience Dive', 'Experience Discipline']]
# Out:
#                       Diver         Day  Month  Discipline  Experience Dive  \
# 13306                    ()  2000-01-01      1         2.0                0
# 13343                    ()  2001-11-10     11         2.0                1
# 11224                    ()  2002-07-27      7         2.0                2
# 2639                     ()  2002-10-31     10         2.0                3
# 8973                     ()  2003-05-29      5         2.0                4
# ...                     ...         ...    ...         ...              ...
# 19120  Ícaro Do Valle (BRA)  2019-10-20     10         0.0               17
# 24941           圭一 福里 (JPN)  2022-09-29      9         1.0                0
# 24949           圭一 福里 (JPN)  2022-09-30      9         1.0                1
# 25753            보걸 강 (KOR)  2023-05-25      5         0.0                0
# 26685            이서 양 (KOR)  2023-06-24      6         1.0                0
#
#        Experience Discipline
# 13306                      0
# 13343                      1
# 11224                      2
# 2639                       3
# 8973                       4
# ...                      ...
# 19120                      7
# 24941                      0
# 24949                      1
# 25753                      0
# 26685                      0
#
# [23613 rows x 6 columns]

# %%
df[df['Remarks']=='DQBO']
# Out:
#        Start               Diver  Gender  Discipline  Line Official Top  AP  \
# 9156       2                  ()       1         0.0   NaN        00:00  41
# 9166      12                  ()       1         2.0   NaN        00:00  46
# 5119     289                  ()       1         2.0   NaN        00:00  50
# 9120       7                  ()       1         2.0   NaN        00:00  49
# 14182      3  Adam Sellars (AUS)       0         1.0   NaN        00:00  70
# ...      ...                 ...     ...         ...   ...          ...  ..
# 4293     140     Yuki Muto (JPN)       1         2.0   NaN        00:00  60
# 4295     142     Yuki Muto (JPN)       1         2.0   NaN        00:00  58
# 2893      68     Yuki Muto (JPN)       1         2.0   NaN        00:00  58
# 9482      70     Yuki Muto (JPN)       1         0.0   NaN        00:00  35
# 1758      17     Yuki Muto (JPN)       1         2.0   NaN        00:00  53
#
#          RP Card Points Remarks                          Title Event  \
# 9156   41 m  RED    0.0    DQBO         AIDA Cyprus Depth Games 2011
# 9166   46 m  RED    0.0    DQBO         AIDA Cyprus Depth Games 2011
# 5119   50 m  RED    0.0    DQBO              World Championship 2012
# 9120   49 m  RED    0.0    DQBO         AIDA CYPRUS Depth Games 2012
# 14182  70 m  RED    0.0    DQBO   AIDA World Depth Championship 2017
# ...     ...  ...    ...     ...                                  ...
# 4293   60 m  RED    0.0    DQBO            Suunto Vertical Blue 2012
# 4295   58 m  RED    0.0    DQBO            Suunto Vertical Blue 2012
# 2893   58 m  RED    0.0    DQBO            Suunto Vertical Blue 2015
# 9482   35 m  RED    0.0    DQBO  2015 AIDA Depth World Championships
# 1758   53 m  RED    0.0    DQBO            Asian Freediving Cup 2017
#
#                Event Type         Day      Category Event  Month  \
# 9156    Depth Competition  2011-10-16               other     10
# 9166    Depth Competition  2011-10-16               other     10
# 5119   World Championship  2012-09-09  World Championship      9
# 9120    Depth Competition  2012-10-14               other     10
# 14182  World Championship  2017-08-23  World Championship      8
# ...                   ...         ...                 ...    ...
# 4293    Depth Competition  2012-11-20                  VB     11
# 4295    Depth Competition  2012-11-20                  VB     11
# 2893    Depth Competition  2015-04-27                  VB      4
# 9482   World Championship  2015-09-11  World Championship      9
# 1758    Depth Competition  2017-06-03               other      6
#
#        Experience Dive  Experience Discipline
# 9156                15                      1
# 9166                16                     12
# 5119                20                     14
# 9120                22                     15
# 14182                3                      1
# ...                ...                    ...
# 4293                15                     12
# 4295                17                     14
# 2893                26                     21
# 9482                33                      3
# 1758                37                     28
#
# [381 rows x 18 columns]

# %%
# Analyzing the 'Remarks' column in detail to identify different types of comments
remarks_counts = df['Remarks'].value_counts()

# Displaying the most common remarks for analysis
remarks_counts.head(30)
# Out:
# Remarks
# OK                    8628
# Ok                    5341
# -                     2555
# PEN                   2219
# No tag,rp<ap           484
# DQSP                   439
# DQBO                   381
# No tag,under ap        353
# NR                     346
# DQOTHER                251
# No tag                 245
# Dqsp                   186
# Rpap,no tag            166
# DNS                     93
# Early Turn, No Tag      85
# Pen, no tag             77
# Dqbo-surface            76
# Dqbo                    73
# National Record         65
# Dqairways               64
# Dqbo-uw                 58
# SHORT & NO TAG          54
# Dqother                 50
# Short, no tag           50
# W                       46
# Short                   46
# Early                   43
# Early turn, no tag      37
# Dqpull                  34
# DQ BO                   33
# Name: count, dtype: int64

# %%
df['Remarks']
# Out:
# 13306      OK
# 13343      OK
# 11224      OK
# 2639       OK
# 8973      PEN
#          ...
# 19120      Ok
# 24941    Dqsp
# 24949      Ok
# 25753      Ok
# 26685    Dqsp
# Name: Remarks, Length: 23613, dtype: object

# %%
for value in df["Remarks"].value_counts().index:
    print(value)
# Out:
# OK
# Ok
# -
# PEN
# No tag,rp<ap
# DQSP
# DQBO
# No tag,under ap
# NR
# DQOTHER
# No tag
# Dqsp
# Rpap,no tag
# DNS
# Early Turn, No Tag
# Pen, no tag
# Dqbo-surface
# Dqbo
# National Record
# Dqairways
# Dqbo-uw
# SHORT & NO TAG
# Dqother
# Short, no tag
# W
# Short
# Early
# Early turn, no tag
# Dqpull
# DQ BO
# Grab
# DQ SP
# No tag,rp<ap,dqother
# No tag,rp<ap,dqsp
# Early turn
# RP<AP no tag
# No tag,under ap,dqsp
# Pen, Short, no tag
# BO
# Other
# Dqsp,dqairways
# SP
# National record
# 0
# Short, tag
# Early Turn, Tag
# RP<AP
# Pen
# Y
# No tag & tag
# Dqairways,dqbo-surface
# No tag,under ap,dqpull
# Rpap,no tag,dqsp
# ET
# RP<AP No tag
# Short,no tag,rp<ap
# DQ Pull
# Early turn and No tag
# Short no tag
# AP>RP no tag
# Pull
# ET NO TAG
# No tag,rp<ap,dqairways
# Dqtouch
# DQPULL
# WR
# Early turn, Tag
# Early,no tag,rp<ap
# DQ pull
# No Tag
# Tag
# No tag,under ap,dqbo-uw
# SHORT/NO TAG
# EARLY TURN+MISSING TAG
# Early Turn
# Short/No tag
# Other,no tag,rp<ap
# Grab,no tag,under ap
# Grab,no tag,rp<ap
# Early turn, no tag.
# Airway
# No tag,under ap,dqother
# SHORT, TAG
# No tag,dqcheck-in
# Short, No Tag
# ET(-4), no Tag(-1)
# Dqother, pull
# R
# No tag,rp<ap,dqbo
# Airways
# Rpap,no tag,early
# AP>RP, no tag
# Rpap,no tag,rp<ap
# No tag & short
# Earlystart
# Dqlatestart,no tag
# Pen, early turn and no tag
# Other,no tag
# Hong Kong NR
# DIS
# Short-tag
# PB
# Early turn, No Tag
# DQ Airways
# ET(-6), no Tag(-1)
# CR
# CWT bi fins
# DQBO (airways)
# NATIONAL RECORD
# No tag,under ap,dqtouch
# Short,no tag,under ap
# Dqsp,dqtouch
# Early Turn，no tag
# Dqbo-uw,dqpull
# National
# CWT BI FINS
# Rpap,no tag,dqpull
# Pulling
# Turn,rpap,no tag
# DQAirway
# No tag,dqother
# Early Warm Up
# OK PEN
# Rpap,no tag,dqsp,dqpull
# DQ BO Airways
# DQ SP Pull
# DQ BO Dip
# NO tag
# PULL
# Dqlatestart
# Korean National Record
# RP<AP No Tag
# Short no tag.
# Dqcheck-in
# Short/Tag
# No tag, early turn
# Grab,pull
# Rpap,no tag,dqbo-uw
# Dqother, Touch
# TAG
# RP<AP, no tag.
# Early Turn， no tag
# DQAirways
# Macao NR
# Early start
# Dqbo,dqsp
# Dqsp,dqother
# No remarks
# Grab,dqpull
# AP<RP No tag
# LATE CHECKING
# Turn,no tag,rp<ap
# Dqairways,dqtouch
# No tag,dqairways
# Early Start
# SHORT
# White Card
# DQOTHER (pull)
# Surface BO
# DQBO surface
# Dqother,dqpull
# Black Out
# Short , no tag
# Turned early, No Tag
# Grab start
# No tag,rp<ap,dqsp,dqother
# 0:52 Dive Time ZWE National Record Claimed
# Dqbo,dqsp,dqtouch
# DQSP + short, tag
# 1:42 Dive Time
# 2:13 Dive Time
# White Card CWTB NZ Mens National Record
# DQ Other
# Pen, lanyard
# 2:21 Dive Time
# DQBO AIRWAYS
# Early Turn, No Tag, Grab
# Grab x 2
# Total Dive Time: :55
# Total dive time 1:19
# DQSP (not finished), short, tag
# White Card PB Equals CWTB NZ Male National Record
# Israeli NR
# EARLY TURN + MISSING TAG
# RED DQSP
# Pen, grab
# PEN GRAB
# DQpull
# Coach Dive
# Airway Dip
# Dqairways,dqsp
# DQ OTHER TOUCH
# DQ Double Pull
# RP<AP, no tag
# Other,dqairways
# Dqother, no tag
# DQ OTHER
# Bo
# Early,grab
# Turn,no tag,under ap
# No tag,rp<ap,dqother,dqairways
# Dqsp,dqairways,dqtouch,dqbo-surface
# DQOTHER/Pull
# DQ AIRWAY
# DQ TOUCH
# DQ SP (16s)
# Rpap,no tag,grab
# No tag,rp<ap,dqcheck-in
# Pen, et+grab
# DQ Assisted
# DQSP (not preformed), short-tag
# Early Start 1sec
# Rpap,no tag,earlystart
# Bifins
# Early turn, No tag
# DQOTHER, PULLING, NO TAG
# DQBO-SURFACE
# ET(-6) ,no Tag (-1)
# AP<RP, no tag, Y-ET
# Pull，SP
# DQairway
# ET(-16),no Tag(-1)
# Lanyard
# No tag,dqlatestart
# New National Record claimed for MUS. in CWT
# PB - New National Record for MUS claimed.
# Rpap,no tag,dqother
# Early,start,no tag,rp<ap,dqsp,dqairways
# No tag,under ap,dqtouch,dqpull
# DQOTHER - Airways
# ET(-5), Grab(-5),no Tag(-1)
# ET(-8), no Tag(-1)
# Safety help to surface
# AIRWAY
# DQSP (airway)
# DQ airways, start
# ET Tag
# No tag,under ap,dqairways
# Continental record
# DIP
# DQ BO Pull
# Dqsp,no tag,rp<ap
# Dip
# 1:03 Dive Time Turned Early, No Tag
# Early start, no tag
# Rpap,no tag,dqairways,dqsp
# Assist
# Under ap
# Dqairways,dqbo-surface,dqpull
# Dqairways,dqsp,dqbo-surface
# Dqbo,dqairways
# Rpap,no tag,dqbo-surface
# SP ET
# Turn
# DQ PULL
# No tag,dqsp,under ap
# Y-before OT
# DEU NR
# ET(-57), no Tag(-1)
# DQ Other, Pull after 2m grab zone
# NO TAG
# DQ late start
# DQ
# EARLY TURN+MISSIG TAG
# Depart av to
# Start
# 1:35 Dive Time
# 0:59 ZWE National Record Claimed
# Total Dive Time: :45
# Grab,dqbo-surface,dqpull
# Short/no tag
# Yellow Card, turned early , no tag
# Short, Tag, Grab Total Dive Time: 1:27
# Total Dive Time: 1:21
# Rp<ap
# Other,early,no tag,rp<ap
# No tag,under ap,dqsp,dqpull
# DQSP on National record
# DQ Surface dip airways.
# NR Early turn, no tag
# Grab,no tag,rp<ap,dqpull
# No Tag, Early Turn
# DQ PIP
# DQ ??
# Short Tag
# National Record for Estonia
# National Record for Estonia.
# Submerge airwais
# DQ, SP
# RED (SP + EARLY START 20s)
# National Record for Israel.
# GRAB + MISSING TAG
# DSN
# DQOTHER - pulling
# DQOTHER - Pulling
# DQPulling
# Early turn, tag
# Dqbo-surface,dqpull
# Dqbo-surface,dqairways
# Dqsp,dqpull
# DQ, Weight
# Dqsp,dqbo-surface
# Dqother,dqairways,dqbo-surface
# DQ Pull surface
# DQ Late Start
# Rpap,no tag,dqcheck-in
# Touch
# DQ PULLING
# World Record
# Rpap,no tag,dqbo-surface,dqpull
# Rpap,no tag,dqsp,dqairways,dqpull
# 78
# No tag,rp<ap,dqpull
# No Tag, early turn
# Dqtouch,dqairways
# DQSP OT
# YELLOW (AP>RP)
# 1:27 Dive Time
# 1:01 Dive TIme
# 1:22 Dive Time
# Bi-Fins
# DQ SP (16S)
# Rpap,no tag,dqpull,dqother
# Early, No tag
# SP& PULL & BO
# Short tag
# Dqother,dqbo-surface
# DQSP airways
# DQBO (surface)
# Grab at start
# Early,no tag,rp<ap,dqsp
# Total Dive Time: :50
# Total Dive Time: 1:09
# SP PENALTY
# No tag,dqbo-surface
# No tag,rp<ap,dqbo-surface
# Korea Female National Record
# Early Turn, No Tag, 2x Grab
# White Card CWTB NZ Female National Record
# Red Card , got entangled at base plate - Safeties released her.
# White Card PB & CWTB NZ National Record.
# Tag, rpap
# Short tag, early turn
# Total Dive Time 1:03
# Short, Tag Total Dive Time: 1:07
# ET(-11), no Tag(-1)
# DQOTHER, pulling
# Double Turn
# Dqsp,dqother,dqpull
# DQ OTHER Arways
# Short, Tag (Airway dip at Surface) Total Dive Time: 1 second
# EARLY TURN
# PEN OTHER
# Short/ No tag
# DQSP (>15 s)
# EARLY
# Red DQ AIRWAYS
# Dqother, DNS, no tag
# Dqtouch,dqpull
# Short no Tag.
# SP Penalty
# Rpap,no tag,dqpull,dqsp
# Dqsp,no tag
# Short, Tag Total Dive Time: 1:48
# ET(-7), no Tag(-1)
# Coach Diving
# Dqairways,dqpull
# Sort no tag
# DQBO (airways), short-tag
# National Record for Spain
# National Record for Spain.
# RP AP, no tag, Y-ET
# Total Dive Time: :53
# Turned Early No Tag 1:26 Dive Time
# 2:03 Dive Time
# 1:36 Dive Time
# Short, Tag Total Dive Time: 1:19
# Dqsp, airways
# DQSP (sequence)
# No tag,under ap,dqbo-surface
# Dqairways,no tag,rp<ap
# Rpap,no tag,dqsp,dqother
# No tag,under ap,dqsp,dqtouch
# DQ PULL START
# Taiwan National Record
# Surface grab
# NR (fresh water)
# DQ Pull Start
# No tag,under ap,dqcheck-in
# ET(-10), no Tag(-1)
# Rpap,no tag,turn,early

# %%
# Adding a new column 'Syncope' to classify each dive as syncope (1) or non-syncope (0)
df['Syncope'] = df['Remarks'].apply(lambda x: 1 if 'DQBO' in str(x) or 'Dqbo-surface' in str(x) else 0)

# Display the first few rows of the modified dataframe to verify the changes
df.head()
# Out:
#        Start Diver  Gender  Discipline  Line Official Top  AP    RP    Card  \
# 13306    136    ()       1         2.0   NaN        00:00   0  37 m   WHITE
# 13343    140    ()       1         2.0   NaN        00:00   0  40 m   WHITE
# 11224     10    ()       1         2.0   NaN        00:00   0  31 m   WHITE
# 2639     162    ()       1         2.0   NaN        00:00   0  33 m   WHITE
# 8973     137    ()       1         2.0   NaN        00:00  34  32 m  YELLOW
#
#       Points Remarks                             Title Event  \
# 13306   37.0      OK         Compiled rankings for year 2000
# 13343   40.0      OK         Compiled rankings for year 2001
# 11224   31.0      OK  1st Portuguese Freediving Championship
# 2639    33.0      OK                   AIDA Pacific Cup 2002
# 8973    12.0     PEN        Sony Freediver Open Classic 2003
#
#               Event Type         Day Category Event  Month  Experience Dive  \
# 13306        Competition  2000-01-01          other      1                0
# 13343        Competition  2001-11-10          other     11                1
# 11224        Competition  2002-07-27          other      7                2
# 2639   Mixed Competition  2002-10-31          other     10                3
# 8973   Mixed Competition  2003-05-29          other      5                4
#
#        Experience Discipline  Syncope
# 13306                      0        0
# 13343                      1        0
# 11224                      2        0
# 2639                       3        0
# 8973                       4        0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

data = df

# Supprimer ou remplacer les valeurs manquantes
data = data.fillna(method='ffill') 
data['Day'] = pd.to_datetime(data['Day'])
data.sort_values(by=['Diver', 'Day'], inplace=True)
data['Experience'] = data.groupby('Diver').cumcount()
# Encoder les variables catégorielles
label_encoders = {}
for column in ['Gender', 'Discipline', 'Event Type']:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# Diviser les données en ensembles d'entraînement et de test
X = data[['Discipline', 'AP', 'Gender', 'Event Type', 'Experience']]
y = data['Syncope']  # Assurez-vous que 'Syncope' est votre variable cible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


# Entraîner un modèle de régression logistique
model = LogisticRegression()
model.fit(X_train, y_train)

# Évaluer le modèle
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15296\712348745.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill')
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4629
#            1       0.00      0.00      0.00        94
#
#     accuracy                           0.98      4723
#    macro avg       0.49      0.50      0.49      4723
# weighted avg       0.96      0.98      0.97      4723
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
data[data['Syncope']==1].count()
# Out:
# Start                    468
# Diver                    468
# Gender                   468
# Discipline               468
# Line                     464
# Official Top             468
# AP                       468
# RP                       468
# Card                     468
# Points                   468
# Remarks                  468
# Title Event              468
# Event Type               468
# Day                      468
# Category Event           468
# Month                    468
# Experience Dive          468
# Experience Discipline    468
# Syncope                  468
# Experience               468
# dtype: int64

# %%
df[df['Syncope']==0].count()
# Out:
# Start                    23145
# Diver                    23145
# Gender                   23145
# Discipline               23145
# Line                      3217
# Official Top             23145
# AP                       23145
# RP                       23145
# Card                     23145
# Points                   23145
# Remarks                  23140
# Title Event              23145
# Event Type               23145
# Day                      23145
# Category Event           23145
# Month                    23145
# Experience Dive          23145
# Experience Discipline    23145
# Syncope                  23145
# dtype: int64

# %%
df['Remarks'].value_counts()
# Out:
# Remarks
# OK                            8628
# Ok                            5341
# -                             2555
# PEN                           2219
# No tag,rp<ap                   484
#                               ...
# NR (fresh water)                 1
# DQ Pull Start                    1
# No tag,under ap,dqcheck-in       1
# ET(-10), no Tag(-1)              1
# Rpap,no tag,turn,early           1
# Name: count, Length: 391, dtype: int64

# %%
df['Category Event'].value_counts()
# Out:
# Category Event
# other                 16425
# World Championship     3720
# VB                     1836
# Panglao                 992
# NAC                     640
# Name: count, dtype: int64
